# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv("/Users/mkr4014/Desktop/CTAP/ctap.csv")

# %%
df = df.drop(columns = ['Unnamed: 0','LINE','FLO_LEAK_PHILLIPS','FLO_LEAK_RES_MED','FLO_LEAK_OTHER','RES_MED_PRES','PHILIPS_PRES','RECORDED_TIME','CONTACT_DATE'])

# %%
df_30 = df[df['DAYS_ON']<=30]
df_60 = df[(df['DAYS_ON']>30) & (df['DAYS_ON']<=60)]
df_90 = df[(df['DAYS_ON']>60) & (df['DAYS_ON']<=90)]
df_120 = df[(df['DAYS_ON']>90) & (df['DAYS_ON']<=120)]
df_150 = df[(df['DAYS_ON']>120) & (df['DAYS_ON']<=150)]
df_180 = df[(df['DAYS_ON']>150) & (df['DAYS_ON']<=180)]

# %%
df_30_agg = df_30.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})
df_60_agg = df_60.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})
df_90_agg = df_90.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})
df_120_agg = df_120.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})
df_150_agg = df_150.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})
df_180_agg = df_180.groupby('MRN').agg({'FLO_AHI_RAW_VALUE': ['mean', 'std'],'FLO_FACE_TIME_VALUE': ['mean', 'std'],'Leak_Pressure': ['mean', 'std'],'Pressure': ['mean', 'std']})

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.mixture import GaussianMixture as mix
from sklearn.cluster import KMeans as KM

# %%
'''df_1 = df_30_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]
df_2 = df_60_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]
df_3 = df_90_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]
df_4 = df_120_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]
df_5 = df_150_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]
df_6 = df_180_agg[['FLO_AHI_RAW_VALUE','FLO_FACE_TIME_VALUE','Leak_Pressure','Pressure']]'''

# %%
'''df_1 = df_30_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]
df_2 = df_60_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]
df_3 = df_90_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]
df_4 = df_120_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]
df_5 = df_150_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]
df_6 = df_180_agg[['FLO_FACE_TIME_VALUE','FLO_AHI_RAW_VALUE']]'''

# %%
df_1 = df_30_agg['FLO_FACE_TIME_VALUE']
df_2 = df_60_agg['FLO_FACE_TIME_VALUE']
df_3 = df_90_agg['FLO_FACE_TIME_VALUE']
df_4 = df_120_agg['FLO_FACE_TIME_VALUE']
df_5 = df_150_agg['FLO_FACE_TIME_VALUE']
df_6 = df_180_agg['FLO_FACE_TIME_VALUE']

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_1) for n in n_components]
plt.plot(n_components, [m.bic(df_1) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_1) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_2) for n in n_components]
plt.plot(n_components, [m.bic(df_2) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_2) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_3) for n in n_components]
plt.plot(n_components, [m.bic(df_3) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_3) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_4) for n in n_components]
plt.plot(n_components, [m.bic(df_4) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_4) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_5) for n in n_components]
plt.plot(n_components, [m.bic(df_5) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_5) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_6) for n in n_components]
plt.plot(n_components, [m.bic(df_6) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_6) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_comp_final = 4
model_1_gm = mix(n_comp_final, random_state=0).fit(df_1)
model_2_gm = mix(n_comp_final, random_state=0).fit(df_2)
model_3_gm = mix(n_comp_final, random_state=0).fit(df_3)
model_4_gm = mix(n_comp_final, random_state=0).fit(df_4)
model_5_gm = mix(n_comp_final, random_state=0).fit(df_5)
model_6_gm = mix(n_comp_final, random_state=0).fit(df_6)
labels_1_gm = model_1_gm.predict(df_1)
labels_2_gm = model_2_gm.predict(df_2)
labels_3_gm = model_3_gm.predict(df_3)
labels_4_gm = model_4_gm.predict(df_4)
labels_5_gm = model_5_gm.predict(df_5)
labels_6_gm = model_6_gm.predict(df_6)
df_1['cluster_1_gm'] = labels_1_gm
df_2['cluster_2_gm'] = labels_2_gm
df_3['cluster_3_gm'] = labels_3_gm
df_4['cluster_4_gm'] = labels_4_gm
df_5['cluster_5_gm'] = labels_5_gm
df_6['cluster_6_gm'] = labels_6_gm

# %%
from sklearn.preprocessing import StandardScaler
X_1 = df_1.values
X_2 = df_2.values
X_3 = df_3.values
X_4 = df_4.values
X_5 = df_5.values
X_6 = df_6.values
scaler_1 = StandardScaler()
scaler_2 = StandardScaler()
scaler_3 = StandardScaler()
scaler_4 = StandardScaler()
scaler_5 = StandardScaler()
scaler_6 = StandardScaler()
scaler_1.fit(X_1)
scaler_2.fit(X_2)
scaler_3.fit(X_3)
scaler_4.fit(X_4)
scaler_5.fit(X_5)
scaler_6.fit(X_6)
X_1_scaled = scaler_1.transform(X_1)
X_2_scaled = scaler_2.transform(X_2)
X_3_scaled = scaler_3.transform(X_3)
X_4_scaled = scaler_4.transform(X_4)
X_5_scaled = scaler_5.transform(X_5)
X_6_scaled = scaler_6.transform(X_6)
df_1_scaled=pd.DataFrame(data=X_1_scaled,columns = df_1.columns, index = df_1.index)
df_2_scaled=pd.DataFrame(data=X_2_scaled,columns = df_2.columns, index = df_2.index)
df_3_scaled=pd.DataFrame(data=X_3_scaled,columns = df_3.columns, index = df_3.index)
df_4_scaled=pd.DataFrame(data=X_4_scaled,columns = df_4.columns, index = df_4.index)
df_5_scaled=pd.DataFrame(data=X_5_scaled,columns = df_5.columns, index = df_5.index)
df_6_scaled=pd.DataFrame(data=X_6_scaled,columns = df_6.columns, index = df_6.index)

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_1_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_1_scaled) for m in models], label='score')
plt.plot(n_components, [m.aic(df_1_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_2_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_2_scaled) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_2_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_3_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_3_scaled) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_3_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_4_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_4_scaled) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_4_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_5_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_5_scaled) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_5_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [mix(n, random_state=0).fit(df_6_scaled) for n in n_components]
plt.plot(n_components, [m.bic(df_6_scaled) for m in models], label='BIC')
plt.plot(n_components, [m.aic(df_6_scaled) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_comp_final = 4
model_1_scaled_gm = mix(n_comp_final, random_state=0).fit(df_1_scaled)
model_2_scaled_gm = mix(n_comp_final, random_state=0).fit(df_2_scaled)
model_3_scaled_gm = mix(n_comp_final, random_state=0).fit(df_3_scaled)
model_4_scaled_gm = mix(n_comp_final, random_state=0).fit(df_4_scaled)
model_5_scaled_gm = mix(n_comp_final, random_state=0).fit(df_5_scaled)
model_6_scaled_gm = mix(n_comp_final, random_state=0).fit(df_6_scaled)
labels_1_scaled_gm = model_1_scaled_gm.predict(df_1_scaled)
labels_2_scaled_gm = model_2_scaled_gm.predict(df_2_scaled)
labels_3_scaled_gm = model_3_scaled_gm.predict(df_3_scaled)
labels_4_scaled_gm = model_4_scaled_gm.predict(df_4_scaled)
labels_5_scaled_gm = model_5_scaled_gm.predict(df_5_scaled)
labels_6_scaled_gm = model_6_scaled_gm.predict(df_6_scaled)
df_1['cluster_1_scaled_gm'] = labels_1_scaled_gm
df_2['cluster_2_scaled_gm'] = labels_2_scaled_gm
df_3['cluster_3_scaled_gm'] = labels_3_scaled_gm
df_4['cluster_4_scaled_gm'] = labels_4_scaled_gm
df_5['cluster_5_scaled_gm'] = labels_5_scaled_gm
df_6['cluster_6_scaled_gm'] = labels_6_scaled_gm

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_1_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_1_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_2_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_2_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_3_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_3_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_4_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_4_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_5_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_5_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
n_components = np.arange(1, 21)
models = [KM(n, random_state=0).fit(df_6_scaled) for n in n_components]
plt.plot(n_components, [-m.score(df_6_scaled) for m in models], label='score')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
from sklearn.cluster import KMeans as KM
n_comp_final = 4
model_1_scaled_KM = KM(n_comp_final, random_state=0).fit(df_1)
model_2_scaled_KM = KM(n_comp_final, random_state=0).fit(df_2)
model_3_scaled_KM = KM(n_comp_final, random_state=0).fit(df_3)
model_4_scaled_KM = KM(n_comp_final, random_state=0).fit(df_4)
model_5_scaled_KM = KM(n_comp_final, random_state=0).fit(df_5)
model_6_scaled_KM = KM(n_comp_final, random_state=0).fit(df_6)
labels_1_scaled_KM = model_1_scaled_KM.predict(df_1)
labels_2_scaled_KM = model_2_scaled_KM.predict(df_2)
labels_3_scaled_KM = model_3_scaled_KM.predict(df_3)
labels_4_scaled_KM = model_4_scaled_KM.predict(df_4)
labels_5_scaled_KM = model_5_scaled_KM.predict(df_5)
labels_6_scaled_KM = model_6_scaled_KM.predict(df_6)
df_1['cluster_1_scaled_KM'] = labels_1_scaled_KM
df_2['cluster_2_scaled_KM'] = labels_2_scaled_KM
df_3['cluster_3_scaled_KM'] = labels_3_scaled_KM
df_4['cluster_4_scaled_KM'] = labels_4_scaled_KM
df_5['cluster_5_scaled_KM'] = labels_5_scaled_KM
df_6['cluster_6_scaled_KM'] = labels_6_scaled_KM

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2,3,1)
plt.scatter(df_1['mean'].values, df_1['std'].values, c=df_1['cluster_1_scaled_KM'].values, s=40, cmap='viridis');
plt.title('First period')
plt.subplot(2,3,2)
plt.scatter(df_2['mean'].values, df_2['std'].values, c=df_2['cluster_2_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Second period')
plt.subplot(2,3,3)
plt.scatter(df_3['mean'].values, df_3['std'].values, c=df_3['cluster_3_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Third period')
plt.subplot(2,3,4)
plt.scatter(df_4['mean'].values, df_4['std'].values, c=df_4['cluster_4_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Fourth period')
plt.subplot(2,3,5)
plt.scatter(df_5['mean'].values, df_5['std'].values, c=df_5['cluster_5_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Fifth period')
plt.subplot(2,3,6)
plt.scatter(df_6['mean'].values, df_6['std'].values, c=df_6['cluster_6_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Sixth period')
# Out:
# Text(0.5, 1.0, 'Sixth period')

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2,3,1)
plt.scatter(df_1['mean'].values, df_1['std'].values, c=df_1['cluster_1_scaled_gm'].values, s=40, cmap='viridis');
plt.title('First period')
plt.subplot(2,3,2)
plt.scatter(df_2['mean'].values, df_2['std'].values, c=df_2['cluster_2_scaled_gm'].values, s=40, cmap='viridis');
plt.title('Second period')
plt.subplot(2,3,3)
plt.scatter(df_3['mean'].values, df_3['std'].values, c=df_3['cluster_3_scaled_gm'].values, s=40, cmap='viridis');
plt.title('Third period')
plt.subplot(2,3,4)
plt.scatter(df_4['mean'].values, df_4['std'].values, c=df_4['cluster_4_scaled_gm'].values, s=40, cmap='viridis');
plt.title('Fourth period')
plt.subplot(2,3,5)
plt.scatter(df_5['mean'].values, df_5['std'].values, c=df_5['cluster_5_scaled_gm'].values, s=40, cmap='viridis');
plt.title('Fifth period')
plt.subplot(2,3,6)
plt.scatter(df_6['mean'].values, df_6['std'].values, c=df_6['cluster_6_scaled_gm'].values, s=40, cmap='viridis');
plt.title('Sixth period')
# Out:
# Text(0.5, 1.0, 'Sixth period')

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2,3,1)
plt.scatter(df_1['mean'].values, df_1['std'].values, c=df_1['cluster_1_gm'].values, s=40, cmap='viridis');
plt.title('First period')
plt.subplot(2,3,2)
plt.scatter(df_2['mean'].values, df_2['std'].values, c=df_2['cluster_2_gm'].values, s=40, cmap='viridis');
plt.title('Second period')
plt.subplot(2,3,3)
plt.scatter(df_3['mean'].values, df_3['std'].values, c=df_3['cluster_3_gm'].values, s=40, cmap='viridis');
plt.title('Third period')
plt.subplot(2,3,4)
plt.scatter(df_4['mean'].values, df_4['std'].values, c=df_4['cluster_4_gm'].values, s=40, cmap='viridis');
plt.title('Fourth period')
plt.subplot(2,3,5)
plt.scatter(df_5['mean'].values, df_5['std'].values, c=df_5['cluster_5_gm'].values, s=40, cmap='viridis');
plt.title('Fifth period')
plt.subplot(2,3,6)
plt.scatter(df_6['mean'].values, df_6['std'].values, c=df_6['cluster_6_gm'].values, s=40, cmap='viridis');
plt.title('Sixth period')
# Out:
# Text(0.5, 1.0, 'Sixth period')

# %%
model_1_means = df_1.groupby('cluster_1_scaled_KM').mean()[['mean','std']]
model_1_means = model_1_means.values
model_2_means = df_2.groupby('cluster_2_scaled_KM').mean()[['mean','std']]
model_2_means = model_2_means.values
model_3_means = df_3.groupby('cluster_3_scaled_KM').mean()[['mean','std']]
model_3_means = model_3_means.values
model_4_means = df_4.groupby('cluster_4_scaled_KM').mean()[['mean','std']]
model_4_means = model_4_means.values
model_5_means = df_5.groupby('cluster_5_scaled_KM').mean()[['mean','std']]
model_5_means = model_5_means.values
model_6_means = df_6.groupby('cluster_6_scaled_KM').mean()[['mean','std']]
model_6_means = model_6_means.values

# %%
new = []
for i in range(len(model_1_means)):
    dist = []
    for j in range(len(model_1_means)):
        dist.append(np.linalg.norm(model_2_means[i]-model_1_means[j]))
    new.append(np.argmin(dist))
cluster_2 = new

# %%
new = []
for i in range(len(model_1_means)):
    dist = []
    for j in range(len(model_1_means)):
        dist.append(np.linalg.norm(model_3_means[i]-model_1_means[j]))
    new.append(np.argmin(dist))
cluster_3 = new

# %%
new = []
for i in range(len(model_1_means)):
    dist = []
    for j in range(len(model_1_means)):
        dist.append(np.linalg.norm(model_4_means[i]-model_3_means[j]))
    new.append(np.argmin(dist))
cluster_4 = new

# %%
new = []
for i in range(len(model_1_means)):
    dist = []
    for j in range(len(model_1_means)):
        dist.append(np.linalg.norm(model_5_means[i]-model_1_means[j]))
    new.append(np.argmin(dist))
cluster_5 = new

# %%
new = []
for i in range(len(model_1_means)):
    dist = []
    for j in range(len(model_1_means)):
        dist.append(np.linalg.norm(model_6_means[i]-model_1_means[j]))
    new.append(np.argmin(dist))
cluster_6 = new

# %%
old = df_2['cluster_2_scaled_KM'].values
for i in range(len(old)):
    old[i] = cluster_2[old[i]]
df_2['cluster_2_scaled_KM'] = old

# %%
old = df_3['cluster_3_scaled_KM'].values
for i in range(len(old)):
    old[i] = cluster_3[old[i]]
df_3['cluster_3_scaled_KM'] = old
old = df_5['cluster_5_scaled_KM'].values
for i in range(len(old)):
    old[i] = cluster_5[old[i]]
df_5['cluster_5_scaled_KM'] = old
old = df_6['cluster_6_scaled_KM'].values
for i in range(len(old)):
    old[i] = cluster_6[old[i]]
df_6['cluster_6_scaled_KM'] = old

# %%
old = df_4['cluster_4_scaled_KM'].values
for i in range(len(old)):
    old[i] = cluster_4[old[i]]
df_4['cluster_4_scaled_KM'] = old

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2,3,1)
plt.scatter(df_1['mean'].values, df_1['std'].values, c=df_1['cluster_1_scaled_KM'].values, s=40, cmap='viridis');
plt.title('First period')
plt.subplot(2,3,2)
plt.scatter(df_2['mean'].values, df_2['std'].values, c=df_2['cluster_2_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Second period')
plt.subplot(2,3,3)
plt.scatter(df_3['mean'].values, df_3['std'].values, c=df_3['cluster_3_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Third period')
plt.subplot(2,3,4)
plt.scatter(df_4['mean'].values, df_4['std'].values, c=df_4['cluster_4_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Fourth period')
plt.subplot(2,3,5)
plt.scatter(df_5['mean'].values, df_5['std'].values, c=df_5['cluster_5_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Fifth period')
plt.subplot(2,3,6)
plt.scatter(df_6['mean'].values, df_6['std'].values, c=df_6['cluster_6_scaled_KM'].values, s=40, cmap='viridis');
plt.title('Sixth period')
# Out:
# Text(0.5, 1.0, 'Sixth period')

# %%
df_1 = df_1.drop(columns = ['mean','std','cluster_1_gm','cluster_1_scaled_gm'])
df_2 = df_2.drop(columns = ['mean','std','cluster_2_gm','cluster_2_scaled_gm'])
df_3 = df_3.drop(columns = ['mean','std','cluster_3_gm','cluster_3_scaled_gm'])
df_4 = df_4.drop(columns = ['mean','std','cluster_4_gm','cluster_4_scaled_gm'])
df_5 = df_5.drop(columns = ['mean','std','cluster_5_gm','cluster_5_scaled_gm'])
df_6 = df_6.drop(columns = ['mean','std','cluster_6_gm','cluster_6_scaled_gm'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-313-f219e6e27d1f> in <module>
# ----> 1 df_1 = df_1.drop(columns = ['mean','std','cluster_1_gm','cluster_1_scaled_gm'])
#       2 df_2 = df_2.drop(columns = ['mean','std','cluster_2_gm','cluster_2_scaled_gm'])
#       3 df_3 = df_3.drop(columns = ['mean','std','cluster_3_gm','cluster_3_scaled_gm'])
#       4 df_4 = df_4.drop(columns = ['mean','std','cluster_4_gm','cluster_4_scaled_gm'])
#       5 df_5 = df_5.drop(columns = ['mean','std','cluster_5_gm','cluster_5_scaled_gm'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ...

# %%
df_final = df_1.join(df_2).join(df_3).join(df_4).join(df_5).join(df_6)

# %%
df_final_sampled = df_final.sample(100)

# %%
df_final_sampled = df_final_sampled.sort_values(by = ['cluster_1_scaled_KM'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (16,10))
plt.pcolor(df_final_sampled,cmap='viridis')
#plt.yticks(np.arange(0.5, len(df_final.index), 1), df_final.index)
plt.xticks(np.arange(0.5, len(df_final_sampled.columns), 1), df_final_sampled.columns)
plt.show()

# %%
df_1.groupby('cluster_1_scaled_KM').size()
# Out:
# cluster_1_scaled_KM
# 0    701
# 1    147
# 2    470
# 3    497
# dtype: int64

# %%
df_1.head()
# Out:
#                                                     cluster_1_scaled_KM
# MRN
# 00088586dfa785603af4356c85c939b7cae3c52a66b2337...                    3
# 000e4c2da2fe0bee25ac0a0bdfead1523accd72e5f5224d...                    2
# 001f0f9c790f13ed62fcb6f33b4bcbb63960033f860aefb...                    3
# 0028d540f95328a8e267a9639d22d8997d856d320930cb9...                    3
# 0036422cbabef6601069119871a7b0f8fd446bcad20c49f...                    2

# %%
df_1_temp = df_1[df_1['cluster_1_scaled_KM']==0]
plt.scatter(df_1_temp['mean'].values, df_1_temp['std'].values, c=df_1_temp['cluster_1_scaled_KM'].values, s=40, cmap='viridis');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-342-1deaf3f00284> in <module>
# ...

# %%
Use all months data for fit
Find clusters for each month based on that
Find the path for them
Find conditional transitional probabilitites - Based on Markov Chain principles.
